# %%
# importing all the libraries

import pandas as pd
import numpy as np
import seaborn as sns
import warnings
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
# Ignore warnings
warnings.simplefilter('ignore')

# %%
# Read the data from CSV files
data = pd.read_csv('zomato.csv', encoding='latin1')
Ccode = pd.read_csv('Country-Code.csv')

# %%
# Create a dictionary to map country codes to country names
tomap = dict(zip(Ccode['Country Code'], Ccode['Country']))

# %%
# Mapping the country name
data['Country_name'] = data['Country Code'].map(tomap)

# %%
# Filtering the India data
data = data[data['Country_name'] == 'India'].reset_index(drop=True)

# %%
# Read the data from CSV files
statedf=pd.read_csv('state-city.csv')
# Create a dictionary to map country codes to country names
tomap2 = dict(zip(statedf['City'], statedf['State']))
# Mapping the state name
data['state'] = data['City'].map(tomap2)

# %%
data['state'].unique()
# Out:
# array(['Uttar Pradesh', 'Gujarat', 'Punjab', 'Maharashtra', 'Karnataka',
#        'Madhya Pradesh', 'Odisha', 'Chandigarh', 'Tamil Nadu',
#        'Uttarakhand', 'Haryana', 'Goa', 'Assam', 'Telangana', 'Rajasthan',
#        'Kerala', 'West Bengal', 'Delhi', 'Bihar', 'Puducherry',
#        'Jharkhand', 'Andhra Pradesh'], dtype=object)

# %%
data[data['state']=='Uttar Pradesh']['City'].unique()
# Out:
# array(['Agra', 'Allahabad', 'Ghaziabad', 'Kanpur', 'Lucknow', 'Noida',
#        'Varanasi'], dtype=object)

# %%
data[data['City']=='Allahabad']
# Out:
#     Restaurant ID            Restaurant Name  Country Code       City  \
# 41        2400020     Aryan Family's Delight             1  Allahabad
# 42        2400148                  Bean Here             1  Allahabad
# 43        2400019                Bikanerwala             1  Allahabad
# 44        2400193                     Dewsis             1  Allahabad
# 45        2400027            Friends Forever             1  Allahabad
# 46       17960073  Hotel Ravisha Continental             1  Allahabad
# 47        2400119                        KFC             1  Allahabad
# 48        2400014                 McDonald's             1  Allahabad
# 49        2400403              Pind Balluchi             1  Allahabad
# 50        2400349                  Pizza Hut             1  Allahabad
# 51        2400279                     Subway             1  Allahabad
# 52        2400017         Tandoor Restaurant             1  Allahabad
# 53       18317988             The BrewMaster             1  Allahabad
# 54        2400144          The Tamarind Tree             1  Allahabad
# 55        2400195              Cafe El Chico             1  Allahabad
# 56        2400052                     Eat On             1  Allahabad
# 57        2400016                  Hot Stuff             1  Allahabad
# 58        2400293                   Paradise             1  Allahabad
# 59        2400009                Sagar Ratna             1  Allahabad
# 60        2400010           Moti Mahal Delux             1  Allahabad
#
#                                               Address  \
# 41  Ground Floor, Vinayak City Centre, Sardar Pate...
# 42  Vinayak Pushp, 77 Elgin Road, Near Florista, C...
# 43  2A, JMD Bhawan, Strachey Road, Civil Lines, Al...
# 44  2, MG Marg, Opposite Hanuman Mandir, Civil Lin...
# 45   13/13, Sardar Patel Marg, Civil Lines, Allahabad
# 46  57 A, Purshottamdas Tandon Marg, Civil Lines, ...
# 47              P Square Mall, Civil Lines, Allahabad
# 48     Shop 4, 34-B, M G Marg, Civil Lines, Allahabad
# 49     5-A, Sardar Patel Marg, Civil Lines, Allahabad
# 50   31/31, Sardar Patel Marg, Civil Lines, Allahabad
# 51  207/53, Mahatma Gandhi Marg, Civil Lines, Alla...
# 52  17/33, Mahatama Gandhi Marg, Civil Lines, Alla...
# 53       Near Vishal Megamart, Civil Lines, Allahabad
# 54       60 C, Thornhill Road, Civil Lines, Allahabad
# 55         24, Mahatma Gandhi, Civil Lines, Allahabad
# 56  Palace Compound, Near Palace Cinema, MG Marg, ...
# 57  21 C, Lal Bhadhur Shastri Marg, Civil Lines, A...
# 58             19/35, MG Marg, Civil Lines, Allahabad
# 59  3/3, Near Balson Crossing, Hashimpur Road, Tag...
# 60  Second Floor, Vinayak City Center Mall, SP Mar...
#
#                                  Locality  \
# 41                            Civil Lines
# 42                            Civil Lines
# 43                            Civil Lines
# 44                            Civil Lines
# 45                            Civil Lines
# 46                            Civil Lines
# 47                            Civil Lines
# 48                            Civil Lines
# 49                            Civil Lines
# 50                            Civil Lines
# 51                            Civil Lines
# 52                            Civil Lines
# 53                            Civil Lines
# 54                            Civil Lines
# 55                            Civil Lines
# 56                            Civil Lines
# 57                            Civil Lines
# 58                            Civil Lines
# 59                            Tagore Town
# 60  Vinayak City Centre Mall, Civil Lines
#
#                                     Locality Verbose  Longitude   Latitude  \
# 41                            Civil Lines, Allahabad  81.834502  25.454648
# 42                            Civil Lines, Allahabad  81.833167  25.453436
# 43                            Civil Lines, Allahabad  81.832616  25.451517
# 44                            Civil Lines, Allahabad   0.000000   0.000000
# 45                            Civil Lines, Allahabad  81.835585  25.457687
# 46                            Civil Lines, Allahabad   0.000000   0.000000
# 47                            Civil Lines, Allahabad  81.839744  25.449659
# 48                            Civil Lines, Allahabad  81.834279  25.450329
# 49                            Civil Lines, Allahabad   0.000000   0.000000
# 50                            Civil Lines, Allahabad   0.000000   0.000000
# 51                            Civil Lines, Allahabad   0.000000   0.000000
# 52                            Civil Lines, Allahabad  81.860187  25.443994
# 53                            Civil Lines, Allahabad  81.832796  25.451646
# 54                            Civil Lines, Allahabad  81.834841  25.459775
# 55                            Civil Lines, Allahabad  81.836167  25.449872
# 56                            Civil Lines, Allahabad  81.834236  25.450377
# 57                            Civil Lines, Allahabad  81.841889  25.452350
# 58                            Civil Lines, Allahabad  81.831681  25.450317
# 59                            Tagore Town, Allahabad  81.859682  25.457116
# 60  Vinayak City Centre Mall, Civil Lines, Allahabad  81.834492  25.454697
#
#                                             Cuisines  ...  \
# 41             North Indian, South Indian, Fast Food  ...
# 42                                   Cafe, Fast Food  ...
# 43              North Indian, Street Food, Fast Food  ...
# 44                             North Indian, Chinese  ...
# 45                             North Indian, Chinese  ...
# 46               North Indian, South Indian, Chinese  ...
# 47                               American, Fast Food  ...
# 48                                         Fast Food  ...
# 49                             North Indian, Mughlai  ...
# 50                                    Italian, Pizza  ...
# 51          Fast Food, American, Salad, Healthy Food  ...
# 52                             North Indian, Chinese  ...
# 53                    North Indian, Chinese, Italian  ...
# 54                             South Indian, Chinese  ...
# 55                              Continental, Italian  ...
# 56                                      North Indian  ...
# 57                           North Indian, Fast Food  ...
# 58                               Desserts, Fast Food  ...
# 59  South Indian, North Indian, Chinese, Continental  ...
# 60                    Mughlai, North Indian, Chinese  ...
#
#     Has Online delivery Is delivering now Switch to order menu Price range  \
# 41                   No                No                   No           3
# 42                   No                No                   No           2
# 43                   No                No                   No           3
# 44                   No                No                   No           3
# 45                   No                No                   No           3
# 46                   No                No                   No           3
# 47                   No                No                   No           3
# 48                   No                No                   No           2
# 49                   No                No                   No           3
# 50                   No                No                   No           3
# 51                   No                No                   No           2
# 52                   No                No                   No           3
# 53                   No                No                   No           1
# 54                   No                No                   No           3
# 55                   No                No                   No           4
# 56                   No                No                   No           1
# 57                   No                No                   No           3
# 58                   No                No                   No           3
# 59                   No                No                   No           2
# 60                   No                No                   No           3
#
#    Aggregate rating Rating color  Rating text  Votes Country_name  \
# 41              3.4       Orange      Average     57        India
# 42              3.3       Orange      Average     76        India
# 43              3.2       Orange      Average     51        India
# 44              3.4       Orange      Average     99        India
# 45              3.4       Orange      Average     83        India
# 46              3.4       Orange      Average     18        India
# 47              3.4       Orange      Average     58        India
# 48              3.3       Orange      Average     53        India
# 49              3.2       Orange      Average      6        India
# 50              3.4       Orange      Average     35        India
# 51              3.4       Orange      Average     32        India
# 52              3.2       Orange      Average    151        India
# 53              3.3       Orange      Average     49        India
# 54              3.4       Orange      Average    106        India
# 55              3.6       Yellow         Good     59        India
# 56              3.7       Yellow         Good    105        India
# 57              3.5       Yellow         Good    105        India
# 58              3.6       Yellow         Good     57        India
# 59              3.5       Yellow         Good    134        India
# 60              3.3       Orange      Average     58        India
#
#             state
# 41  Uttar Pradesh
# 42  Uttar Pradesh
# 43  Uttar Pradesh
# 44  Uttar Pradesh
# 45  Uttar Pradesh
# 46  Uttar Pradesh
# 47  Uttar Pradesh
# 48  Uttar Pradesh
# 49  Uttar Pradesh
# 50  Uttar Pradesh
# 51  Uttar Pradesh
# 52  Uttar Pradesh
# 53  Uttar Pradesh
# 54  Uttar Pradesh
# 55  Uttar Pradesh
# 56  Uttar Pradesh
# 57  Uttar Pradesh
# 58  Uttar Pradesh
# 59  Uttar Pradesh
# 60  Uttar Pradesh
#
# [20 rows x 23 columns]

# %%
# Selecting useful columns for restaurant recommendation
df = data[['Restaurant Name', 'Address', 'City','state', 'Cuisines', 'Rating text', 'Locality']]

# %%
# Aggregation and summary statistics
for column in df.columns:
    column_counts = df[column].value_counts()  # Count of each category
    column_percentages = df[column].value_counts(normalize=True) * 100  # Percentage of each category
    
    # Create a summary DataFrame
    summary_df = pd.DataFrame({
        'Count': column_counts,
        'Percentage': column_percentages
    })
    
    # Display summary statistics
    print(f"Summary statistics for '{column}':")
    print(summary_df)
    print()
# Out:
# Summary statistics for 'Restaurant Name':
#                           Count  Percentage
# Cafe Coffee Day              83    0.959316
# Domino's Pizza               79    0.913084
# Subway                       63    0.728155
# Green Chick Chop             51    0.589459
# McDonald's                   48    0.554785
# ...                         ...         ...
# Sona Pure Veg Paradise        1    0.011558
# Dimcha                        1    0.011558
# Duke's Pastry Shop            1    0.011558
# Stabbers                      1    0.011558
# Flying Spaghetti Monster      1    0.011558
#
# [6604 rows x 2 columns]
#
# Summary statistics for 'Address':
#                                                     Count  Percentage
# Dilli Haat, INA, New Delhi                             11    0.127138
# Sector 41, Noida                                       11    0.127138
# Greater Kailash (GK) 1, New Delhi                      10    0.115580
# The Imperial, Janpath, New Delhi                        9    0.104022
# Food Court, 3rd Floor, Logix City Centre, Secto...      8    0.092464
# ...                                                   ...         ...
# Shop 3, 25/6, East Patel Nagar, New Delhi               1    0.011558
# 25/35, East Patel Nagar, New Delhi                      1    0.011558
# 1/2, Ground Floor, Opposite Patel Nagar Metro S...      1    0.011558
# 18/27, East Patel Nagar Market, East Patel Naga...      1    0.011558
# 10-50-12/F2, Sai Dakshata Complex, Beside Lenov...      1    0.011558
#
# [8025 rows x 2 columns]
#
# Summary statistics for 'City':
#               Count  Percentage
# New Delhi      5473   63.257050
# Gurgaon        1118   12.921868
# Noida          1080   12.482663
# Faridabad       251    2.901063
# Ghaziabad        25    0.288951
# Ahmedabad        21    0.242718
# Guwahati         21    0.242718
# Lucknow          21    0.242718
# Bhubaneshwar     21    0.242718
# Amritsar         21    0.242718
# Pune             20    0.231160
# Puducherry       20    0.231160
# Patna            20    0.231160
# Ludhiana         20    0.231160
# Ranchi           20    0.231160
# Surat            20    0.231160
# Vadodara         20    0.231160
# Nashik           20    0.231160
# Nagpur           20    0.231160
# Mysore           20    0.231160
# Mumbai           20    0.231160
# Varanasi         20    0.231160
# Mangalore        20    0.231160
# Agra             20    0.231160
# Kochi            20    0.231160
# Kolkata          20    0.231160
# Dehradun         20    0.231160
# Allahabad        20    0.231160
# Aurangabad       20    0.231160
# Bangalore        20    0.231160
# Bhopal           20    0.231160
# Chennai          20    0.231160
# Coimbatore       20    0.231160
# Goa              20    0.231160
# Indore           20    0.231160
# Jaipur           20    0.231160
# Kanpur           20    0.231160
# Vizag            20    0.231160
# Chandigarh       18    0.208044
# Hyderabad        18    0.208044
# Secunderabad      2    0.023116
# Panchkula         1    0.011558
# Mohali            1    0.011558
#
# Summary statistics for 'state':
#                 Count  Percentage
# Delhi            5473   63.257050
# Haryana          1370   15.834489
# Uttar Pradesh    1206   13.938974
# Maharashtra       100    1.155802
# Gujarat            61    0.705039
# Karnataka          60    0.693481
# Punjab             42    0.485437
# Madhya Pradesh     40    0.462321
# Tamil Nadu         40    0.462321
# Odisha             21    0.242718
# Assam              21    0.242718
# West Bengal        20    0.231160
# Jharkhand          20    0.231160
# Puducherry         20    0.231160
# Bihar              20    0.231160
# Goa                20    0.231160
# Kerala             20    0.231160
# Rajasthan          20    0.231160
# Telangana          20    0.231160
# Uttarakhand        20    0.231160
# Andhra Pradesh     20    0.231160
# Chandigarh         18    0.208044
#
# Summary statistics for 'Cuisines':
#                                                     Count  Percentage
# North Indian                                          936   10.818308
# North Indian, Chinese                                 511    5.906149
# Fast Food                                             348    4.022191
# Chinese                                               340    3.929727
# North Indian, Mughlai                                 334    3.860379
# ...                                                   ...         ...
# Chinese, Japanese, Thai, Malaysian, Vietnamese,...      1    0.011558
# North Indian, Street Food, Mughlai                      1    0.011558
# Seafood, South Indian, Andhra, Hyderabadi, Goan         1    0.011558
# Chinese, Fast Food, North Indian, South Indian          1    0.011558
# American, North Indian, Thai, Continental               1    0.011558
#
# [1392 rows x 2 columns]
#
# Summary statistics for 'Rating text':
#            Count  Percentage
# Average     3678   42.510402
# Not rated   2139   24.722607
# Good        1847   21.347665
# Very Good    692    7.998151
# Poor         180    2.080444
# Excellent    116    1.340730
#
# Summary statistics for 'Locality':
#                                      Count  Percentage
# Connaught Place                        122    1.410079
# Rajouri Garden                          99    1.144244
# Shahdara                                87    1.005548
# Defence Colony                          86    0.993990
# Malviya Nagar                           85    0.982432
# ...                                    ...         ...
# Mansingh Road                            1    0.011558
# 12th Square Building, Banjara Hills      1    0.011558
# Gachibowli                               1    0.011558
# Holiday Inn Express & Suites             1    0.011558
# Waltair Uplands                          1    0.011558
#
# [784 rows x 2 columns]

# %%
# Word cloud visualization
for column in df.columns:
    print(f"Word Cloud for '{column}':")
    # Extract the values from the column and convert to a list
    values = df[column].dropna().tolist()

    # Concatenate the values into a single string
    text = ' '.join(values)

    # Create the WordCloud object
    wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

    # Plot the word cloud
    plt.figure(figsize=(10, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()
# Out:
# Word Cloud for 'Restaurant Name':
# Word Cloud for 'Address':
# Word Cloud for 'City':
# Word Cloud for 'state':
# Word Cloud for 'Cuisines':
# Word Cloud for 'Rating text':
# Word Cloud for 'Locality':

# %%
# Heatmap visualization
cross_tab = pd.crosstab(df['City'], df['Rating text'])
plt.figure(figsize=(10, 6))
sns.heatmap(cross_tab, annot=True, fmt='d', cmap='YlGnBu')
plt.title('Heatmap: City vs Rating text')
plt.xlabel('Rating text')
plt.ylabel('City')
plt.show()

# %%
# Perform text preprocessing
# Splitting the text columns into individual words
data['City'] = data['City'].apply(lambda x: x.split())
data['Cuisines'] = data['Cuisines'].apply(lambda x: x.split())
data['Rating text'] = data['Rating text'].apply(lambda x: x.split())
data['Locality'] = data['Locality'].apply(lambda x: x.split())

# Combine the preprocessed columns into a single 'tags' column
data['tags'] = data['Cuisines'] + data['City'] + data['Locality'] + data['Rating text']

# Convert the 'tags' column back to a string
data['tags'] = data['tags'].apply(lambda x: " ".join(x))

# Convert the 'tags' column to lowercase
data['tags'] = data['tags'].apply(lambda x: x.lower())

# %%
# Drop unnecessary columns
data.drop(columns=['City', 'Cuisines', 'Locality', 'Rating text'], inplace=True)

# %%
# Perform stemming on text data
from nltk.stem.porter import PorterStemmer
# Create an instance of PorterStemmer
ps = PorterStemmer()

# Function to apply stemming to a text
def stem(text):
    stemmed_words = []
    
    # Split the text into individual words
    for word in text.split():
        # Apply stemming to each word and add it to the list
        stemmed_words.append(ps.stem(word))
    
    # Join the stemmed words back into a single string
    return " ".join(stemmed_words)

# %%
data['tags'] = data['tags'].apply(stem)

# %%
# Remove stop words using CountVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# Create a CountVectorizer object
# max_features specifies the maximum number of features (words) to keep
# stop_words='english' removes common English words (e.g., 'the', 'and', 'is')
cv = CountVectorizer(max_features=500, stop_words='english')

# Convert the 'tags' column into a matrix of word counts
vectors = cv.fit_transform(data['tags']).toarray()

# %%
# Get the feature names
feature_names = cv.get_feature_names_out()

# %%
# Concatenate the values into a single string
text = ' '.join(feature_names)

# Create the WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(text)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# Compute cosine similarity
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vectors)

def top4_resta(restaurent):
    index = data[data['Restaurant Name'] == restaurent].index[0]
    n = sorted(list(enumerate(similarity[index])), reverse=True, key=lambda x: x[1])
    l_index = []
    count = 0
    
    for i in n:
        if count < 6:
            l_index.append(i[0])
            count += 1
    
    l_index = l_index[1:]
    
    rest = []
    for i in l_index:
        rest.append(data.loc[i]['Restaurant Name'])
    
    return rest

# %%
similarity
# Out:
# array([[1.        , 1.        , 0.94280904, ..., 0.13608276, 0.35355339,
#         0.16666667],
#        [1.        , 1.        , 0.94280904, ..., 0.13608276, 0.35355339,
#         0.16666667],
#        [0.94280904, 0.94280904, 1.        , ..., 0.14433757, 0.375     ,
#         0.1767767 ],
#        ...,
#        [0.13608276, 0.13608276, 0.14433757, ..., 1.        , 0.28867513,
#         0.61237244],
#        [0.35355339, 0.35355339, 0.375     , ..., 0.28867513, 1.        ,
#         0.35355339],
#        [0.16666667, 0.16666667, 0.1767767 , ..., 0.61237244, 0.35355339,
#         1.        ]])

# %%
top4_resta('Desire Foods')
# Out:
# ['Snax Points', 'Rakheja Bakery', 'Momo-Cha', 'China Hot Pot', 'Oregano India']

# %%
df.reset_index(drop=True,inplace=True)

# %%
df[df['Restaurant Name']=="Momo-Cha"]
# Out:
#     Restaurant Name                                            Address  \
# 270        Momo-Cha             Crown Plaza Mall, Sector 15, Faridabad
# 289        Momo-Cha    J-121, Near Lean Wolf Gym, Sector 10, Faridabad
# 315        Momo-Cha        87, Near City Chemist, Sector 15, Faridabad
# 356        Momo-Cha  31, Near HDFC Bank ATM, Sector 17 Market, Sect...
#
#           City    state               Cuisines Rating text  \
# 270  Faridabad  Haryana              Fast Food     Average
# 289  Faridabad  Haryana  North Indian, Chinese     Average
# 315  Faridabad  Haryana     Chinese, Fast Food     Average
# 356  Faridabad  Haryana  North Indian, Chinese     Average
#
#                                    Locality
# 270  Crown Plaza Mall, Sector 15, Faridabad
# 289                               Sector 10
# 315                               Sector 15
# 356                               Sector 17

# %%
import pickle

# %%
pickle.dump(df,open('newdata.pkl','wb'))

# %%
pickle.dump(similarity,open('similarity.pkl','wb'))
